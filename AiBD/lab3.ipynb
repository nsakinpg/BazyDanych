# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)

connection_sqlalchemy = db.connect()

# %%
#1

# %%
df = pd.read_sql('SELECT DISTINCT COUNT(*) FROM category',con=connection_sqlalchemy)
df
# Out:
#    count
# 0     16

# %%
#2

# %%
df = pd.read_sql('SELECT DISTINCT name FROM category ORDER BY name ASC',con=connection_sqlalchemy)
df
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %%
#3

# %%
df = pd.read_sql('SELECT title FROM film ORDER BY release_year ASC LIMIT 1',con=connection_sqlalchemy)
df
# Out:
#              title
# 0  Chamber Italian

# %%
df = pd.read_sql('SELECT title FROM film ORDER BY release_year DESC LIMIT 1',con=connection_sqlalchemy)
df
# Out:
#              title
# 0  Chamber Italian

# %%
#4

# %%
df = pd.read_sql("SELECT COUNT(*) FROM rental WHERE rental_date BETWEEN '2005-07-01' AND '2005-08-01'",con=connection_sqlalchemy)
df
# Out:
#    count
# 0   6709

# %%
df = pd.read_sql("SELECT COUNT(*) FROM rental WHERE rental_date BETWEEN '2010-01-01' AND '2011-02-01'",con=connection_sqlalchemy)
df
# Out:
#    count
# 0      0

# %%
#5

# %%
df = pd.read_sql("SELECT MAX(amount) FROM payment",con=connection_sqlalchemy)
df
# Out:
#      max
# 0  11.99

# %%
#6

# %%
df = pd.read_sql("SELECT * FROM customer LEFT JOIN address ON address.address_id = customer.address_id LEFT JOIN city ON city.city_id = address.city_id LEFT JOIN country ON country.country_id = city.country_id WHERE country IN('Poland')",con=connection_sqlalchemy)
df
# Out:
#    customer_id  store_id first_name  last_name  \
# 0          318         1      Brian      Wyman
# 1          572         1     Sidney   Burleson
# 2          128         1   Marjorie     Tucker
# 3          270         1       Leah     Curtis
# 4          501         1      Ruben      Geary
# 5          571         2    Johnnie   Chisholm
# 6          380         1    Russell    Brinson
# 7          558         1     Jimmie  Eggleston
#
#                                  email  address_id  activebool create_date  \
# 0       brian.wyman@sakilacustomer.org         323        True  2006-02-14
# 1   sidney.burleson@sakilacustomer.org         578        True  2006-02-14
# 2   marjorie.tucker@sakilacustomer.org         132        True  2006-02-14
# 3       leah.curtis@sakilacustomer.org         275        True  2006-02-14
# 4       ruben.geary@sakilacustomer.org         506        True  2006-02-14
# 5  johnnie.chisholm@sakilacustomer.org         577        True  2006-02-14
# 6   russell.brinson@sakilacustomer.org         385        True  2006-02-14
# 7  jimmie.eggleston@sakilacustomer.org         564        True  2006-02-14
#
#               last_update  active  ...  postal_code         phone  \
# 0 2013-05-26 14:49:45.738       1  ...        25787  556100547674
# 1 2013-05-26 14:49:45.738       1  ...        86587  867287719310
# 2 2013-05-26 14:49:45.738       1  ...         4999  973047364353
# 3 2013-05-26 14:49:45.738       1  ...        83565  701767622697
# 4 2013-05-26 14:49:45.738       1  ...        16370   52709222667
# 5 2013-05-26 14:49:45.738       1  ...          943  770864062795
# 6 2013-05-26 14:49:45.738       1  ...        75442  821476736117
# 7 2013-05-26 14:49:45.738       0  ...        97271  970638808606
#
#           last_update city_id             city country_id         last_update  \
# 0 2006-02-15 09:45:30      97        Bydgoszcz         76 2006-02-15 09:45:25
# 1 2006-02-15 09:45:30     133      Czestochowa         76 2006-02-15 09:45:25
# 2 2006-02-15 09:45:30     236  Jastrzebie-Zdrj         76 2006-02-15 09:45:25
# 3 2006-02-15 09:45:30     255           Kalisz         76 2006-02-15 09:45:25
# 4 2006-02-15 09:45:30     314           Lublin         76 2006-02-15 09:45:25
# 5 2006-02-15 09:45:30     409            Plock         76 2006-02-15 09:45:25
# 6 2006-02-15 09:45:30     549            Tychy         76 2006-02-15 09:45:25
# 7 2006-02-15 09:45:30     577          Wroclaw         76 2006-02-15 09:45:25
#
#   country_id  country         last_update
# 0         76   Poland 2006-02-15 09:44:00
# 1         76   Poland 2006-02-15 09:44:00
# 2         76   Poland 2006-02-15 09:44:00
# 3         76   Poland 2006-02-15 09:44:00
# 4         76   Poland 2006-02-15 09:44:00
# 5         76   Poland 2006-02-15 09:44:00
# 6         76   Poland 2006-02-15 09:44:00
# 7         76   Poland 2006-02-15 09:44:00
#
# [8 rows x 25 columns]
